# %% [markdown]
# **Задание 1.** Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2. Напишите код, который проверяет какая из этих строк длиннее.

# %%
phrase_1=input('Введите первую фразу: ')
phrase_2=input('Введите вторую фразу: ') 

if len(phrase_1)>len(phrase_2):
    print("Фраза 1 длиннее фразы 2")
elif len(phrase_2)>len(phrase_1):
    print("Фраза 2 длиннее фразы 1")
else:
    print("Фразы равной длины")
# Out:
# Введите первую фразу: Язык программирования Python
# Введите вторую фразу: Язык программирования R
# Фраза 1 длиннее фразы 2

# %% [markdown]
# **Задание 2.** Дана переменная, в которой хранится четырехзначное число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.

# %%
year=int(input('Введите год: '))

if (year%4!=0):
    print("Обычный год")
elif (year%100==0) and (year%400!=0):
    print("Обычный год")
else:
    print("Високосный год")
# Out:
# Введите год: 2020
# Високосный год

# %% [markdown]
# **Задание 3.** Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.

# %%
day = int(input('Введите день своего рождения: '))
month = input('Введите месяц своего рождения: ')
if month=="январь":
    month_1=1
if month=="февраль":
    month_1=2
if month=="март":
    month_1=3
if month=="апрель":
    month_1=4
if month=="май":
    month_1=5
if month=="июнь":
    month_1=6
if month=="июль":
    month_1=7
if month=="август":
    month_1=8
if month=="сентябрь":
    month_1=9
if month=="октябрь":
    month_1=10
if month=="ноябрь":
    month_1=11
if month=="декабрь":
    month_1=11
if ((day>=23) and (month_1==12)) or ((day<=20) and (month_1==1)):
    print("Ваш знак зодиака: Козерог")
if ((day>=21) and (month_1==1)) or ((day<=19) and (month_1==2)):
    print("Ваш знак зодиака: Водолей")
if ((day>=20) and (month_1==2)) or ((day<=20) and (month_1==3)):
    print("Ваш знак зодиака: Рыбы")
if ((day>=21) and (month_1==3)) or ((day<=20) and (month_1==4)):
    print("Ваш знак зодиака: Овен")
if ((day>=21) and (month_1==4)) or ((day<=21) and (month_1==5)):
    print("Ваш знак зодиака: Телец")
if ((day>=22) and (month_1==5)) or ((day<=21) and (month_1==6)):
    print("Ваш знак зодиака: Близнецы")
if ((day>=22) and (month_1==6)) or ((day<=22) and (month_1==7)):
    print("Ваш знак зодиака: Рак")
if ((day>=23) and (month_1==7)) or ((day<=21) and (month_1==8)):
    print("Ваш знак зодиака: Лев")
if ((day>=22) and (month_1==8)) or ((day<=23) and (month_1==9)):
    print("Ваш знак зодиака: Дева")
if ((day>=24) and (month_1==9)) or ((day<=23) and (month_1==10)):
    print("Ваш знак зодиака: Весы")
if ((day>=24) and (month_1==10)) or ((day<=22) and (month_1==11)):
    print("Ваш знак зодиака: Скорпион")
if ((day>=23) and (month_1==11)) or ((day<=22) and (month_1==12)):
    print("Ваш знак зодиака: Стрелец")
# Out:
# Введите день своего рождения: 18
# Введите месяц своего рождения: сентябрь
# Ваш знак зодиака: Дева

# %% [markdown]
# **Задание 4.** Вам нужно написать программу для подбора упаковок по размерам товара. Размеры хранятся в переменных (в  сантиметрах):\\
#
# * width = 10,
# * length = 205,
# * height = 5,
#
# Используйте следующие правила:
#
# * если каждое из трех измерений менее 15 сантиметров, то выведите на экран “Коробка №1”;
# * если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите “Коробка №2”;
# * если длина товара больше 2 метров, то выводите “Упаковка для лыж”;
# * во всех остальных случаях выводите “Стандартная коробка №3”.

# %%
width = int(input('Введите ширину товара в сантимерах: '))
length = int(input('Введите длину товара в сантиметрах: '))
height = int(input('Введите высоту товара в сантиметрах: '))

if (width<=15) and (length<=15) and (height<=15):
    print("Коробка №1")
elif ((width>15) and (width<=50)) or ((length>15) and (length<=50)) or ((height>15) and (height<=50)):
    print("Коробка №2")
elif (length>200):
    print("Упаковка для лыж")
else:
    print("Стандартная коробка №3")
# Out:
# Введите ширину товара в сантимерах: 50
# Введите длину товара в сантиметрах: 120
# Введите высоту товара в сантиметрах: 201
# Коробка №2

# %% [markdown]
# **Задание 5. (необязательное)** Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет “счастливым”. Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.

# %%
number_of_ticket=int(input('Введите номер билета: '))

s=str(number_of_ticket) #преобразуем введенное число в строку
digit_1=int(s[0]) #преобразуем каждый символ строки в число
digit_2=int(s[1])
digit_3=int(s[2])
digit_4=int(s[3])
digit_5=int(s[4])
digit_6=int(s[5])

#сравниваем сумму первых цифр с суммой последних трех цифр
if (digit_1+digit_2+digit_3==digit_4+digit_5+digit_6):
    print('Ваш билет счастливый')
else:
    print('Ваш билет несчастливый')
# Out:
# Введите номер билета: 125521
# Ваш билет счастливый

# %% [markdown]
# **Задание 6. (необязательное)** Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник). Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#
# * если пользователь выбрал круг, запрашиваем его радиус,
# * если треугольник – длины трех его сторон;
# * если прямоугольник – длины двух его сторон.

# %%
figure=input('Введите тип фигуры: ')

if figure=='Круг':
    
    r=float(input('Введите радиус круга: '))
    
    s=3.14*r**2
    
    print('Площадь круга ', round(s,2))


if figure=='Треугольник':
    
    a=float(input('Введите длину стороны треугольника a : '))
    b=float(input('Введите длину стороны треугольника b : '))
    c=float(input('Введите длину стороны треугольника c : '))
    
    p=(a+b+c)/2
    s=sqrt(p*(p-a)*(p-b)*(p-c))
    
    print('Площадь треугольника ', round(s,2))
            
if figure=='Прямоугольник':
    
    a=float(input('Введите длину стороны прямогольника a : '))
    b=float(input('Введите длину стороны прямоугольника b : '))
    
    s=a*b
    
    print('Площадь прямоугольника ', round(s,2))
# Out:
# Введите тип фигуры: Круг
# Введите радиус круга: 98.5
# Площадь круга  30465.07
